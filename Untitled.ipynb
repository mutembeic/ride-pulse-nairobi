# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Train.csv')
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
df.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Order No                                   21201 non-null  object
#  1   User Id                                    21201 non-null  object
#  2   Vehicle Type                               21201 non-null  object
#  3   Platform Type                              21201 non-null  int64
#  4   Personal or Business                       21201 non-null  object
#  5   Placement - Day of Month                   21201 non-null  int64
#  6   Placement - Weekday (Mo = 1)               21201 non-null  int64
#  7   Placement - Time                           21201 non-null  object
#  8   Confirmation - Day of Month                21201 non-null  int64
#  9   Confirmation - Weekday (Mo = 1)            21201 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Order No                                         0
# User Id                                          0
# Vehicle Type                                     0
# Platform Type                                    0
# Personal or Business                             0
# Placement - Day of Month                         0
# Placement - Weekday (Mo = 1)                     0
# Placement - Time                                 0
# Confirmation - Day of Month                      0
# Confirmation - Weekday (Mo = 1)                  0
# Confirmation - Time                              0
# Arrival at Pickup - Day of Month                 0
# Arrival at Pickup - Weekday (Mo = 1)             0
# Arrival at Pickup - Time                         0
# Pickup - Day of Month                            0
# Pickup - Weekday (Mo = 1)                        0
# Pickup - Time                                    0
# Arrival at Destination - Day of Month            0
# ...

# %%
df['Placement - Time'] = pd.to_datetime(df['Placement - Time'])
df['Arrival at Destination - Time'] = pd.to_datetime(df['Arrival at Destination - Time'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7532\4271404037.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Placement - Time'] = pd.to_datetime(df['Placement - Time'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7532\4271404037.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival at Destination - Time'] = pd.to_datetime(df['Arrival at Destination - Time'])

# %%
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1)    Placement - Time  \
# 0                             5 2025-07-24 09:35:46
# 1                             5 2025-07-24 11:16:16
# 2                             2 2025-07-24 12:39:25
# 3                             5 2025-07-24 09:25:34
# ...

# %%
# Convert day column to padded string (e.g., 9 -> 09)
df['Placement - Day of Month'] = df['Placement - Day of Month'].astype(str).str.zfill(2)

# Convert time to string (just in case it's datetime)
df['Placement - Time'] = df['Placement - Time'].astype(str)

# Combine into full datetime string
df['placement_datetime_str'] = '2019-03-' + df['Placement - Day of Month'] + ' ' + df['Placement - Time']

# Let pandas infer the format automatically
df['placement_datetime'] = pd.to_datetime(df['placement_datetime_str'], errors='coerce')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7532\1208998555.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['placement_datetime'] = pd.to_datetime(df['placement_datetime_str'], errors='coerce')

# %%
df.drop(columns=['Temperature', 'Precipitation in millimeters'], inplace=True)

# %%
rider_trip_counts = df.groupby('Rider Id').size().reset_index(name='Trip Count')
rider_trip_counts
# Out:
#          Rider Id  Trip Count
# 0      Rider_Id_0           1
# 1      Rider_Id_1           1
# 2     Rider_Id_10          51
# 3    Rider_Id_100          99
# 4    Rider_Id_101         183
# ..            ...         ...
# 919  Rider_Id_959          23
# 920   Rider_Id_96         104
# 921   Rider_Id_97           7
# 922   Rider_Id_98           2
# 923   Rider_Id_99          59
#
# [924 rows x 2 columns]

# %%
rider_summary = df.groupby('Rider Id').agg({
    'Distance (KM)': 'mean',
    'Time from Pickup to Arrival': 'mean'
}).reset_index()
rider_summary
# Out:
#          Rider Id  Distance (KM)  Time from Pickup to Arrival
# 0      Rider_Id_0      12.000000                  1393.000000
# 1      Rider_Id_1      11.000000                  1333.000000
# 2     Rider_Id_10       9.490196                   529.098039
# 3    Rider_Id_100       8.171717                  1271.929293
# 4    Rider_Id_101      10.491803                  1755.579235
# ..            ...            ...                          ...
# 919  Rider_Id_959       8.956522                  1556.086957
# 920   Rider_Id_96       9.817308                  1485.163462
# 921   Rider_Id_97      10.571429                   965.857143
# 922   Rider_Id_98      10.000000                  1371.000000
# 923   Rider_Id_99       9.559322                  1681.983051
#
# [924 rows x 3 columns]
